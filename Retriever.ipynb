# %%
from patent_analysis import retriever
import snap

# %matplotlib inline
# Out:
# 2017-07-28 09:15:21,467 [INFO] root: Mongo Version: 3.4.6

# %%
retriever.plot_node_count_per_year()

# %%
retriever.plot_edge_count_per_year()

# %%
retriever.plot_edge_count_per_year(avg=True)

# %%
retriever.plot_degree_distro()

# %%
retriever.plot_nodes_to_edges_count()
